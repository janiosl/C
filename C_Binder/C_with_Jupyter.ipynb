// %% [markdown]
// # Testando C no Jupyter Notebook
//
// Testes básicos da linguagem C com objetivo de avaliar a execução do código através do notebook com Docker criado através do Binder.

// %%
#include <stdio.h>
int main() {
    printf("Hello World\n");
}
// Out:
// Hello World

// %%
#include <stdio.h>
int main()
{
    printf("Testando uso de C no Jupyter Notebook\n\n");
    int k = 1;
    while (k <= 10)
    {
        printf("Rodada %i\n", k);
        k ++;
    }
    return 0;
}
// Out:
// Testando uso de C no Jupyter Notebook
//
// Rodada 1
// Rodada 2
// Rodada 3
// Rodada 4
// Rodada 5
// Rodada 6
// Rodada 7
// Rodada 8
// Rodada 9
// Rodada 10

// %%
#include <stdio.h>
#include <stdlib.h>

int main()
{
    /*char numeroStr[10];*/
    int suc;
    int ant;

    puts("Digite um número: ");
    
    char numeroStr[10] = "7";
    /*Função de interação não funciona no Jupyter*/
    /*fgets(numeroStr, 10, stdin);*/
        

    suc = atoi(numeroStr) + 1;
    ant = atoi(numeroStr) - 1;

    puts("----------------------------------------------");

    printf("Número digitado: %i\nSucessor: %i\nAntecessor: %i\n", atoi(numeroStr), suc, ant);

    puts("----------------------------------------------");

    return 0;
}
// Out:
// Digite um número:
// ----------------------------------------------
// Número digitado: 7
// Sucessor: 8
// Antecessor: 6
// ----------------------------------------------

// %%
#include <stdio.h>

void linha(int tipo)
{
    if (tipo == 2)
        puts("===========================================");
    else if (tipo == 1)
        puts("--------------------------------------------");
}

void cabecalho(char title[])
{
    linha(2);
    printf("%s\n", title);
    linha(2);
}

void rodape()
{
    linha(2);
    puts("Programa Encerrado.\nObrigado. Janio Lima");
    linha(2);
}

int main()
{
    /*float c;*/
    float f;
    char title[] = "GRAUS CELSIUS PARA FAHRENHEIT";

    cabecalho(title);

    
    
    /*
    puts("Digite a temperatura em Graus Célcius °C:");
    Função de interação não funciona no Jupyter
    scanf("%f", &c);
    */
    
    float c = 24.0;
    printf("Temperatura em Graus Célcius: %.1f°C\n", c);

    f = ((c * 9) / 5) + 32;

    linha(1);
    printf("A temperatura convertida é %.1f°F\n", f);

    rodape();

    return 0;
}
// Out:
// ...
// GRAUS CELSIUS PARA FAHRENHEIT
// ...
// Temperatura em Graus Célcius: 24.0°C
// --------------------------------------------
// A temperatura convertida é 75.2°F
// ...
// Programa Encerrado.
// Obrigado. Janio Lima
// ...
